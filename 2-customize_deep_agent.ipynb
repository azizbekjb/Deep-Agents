# %%
#--------------------------START-------------------------
# I have learned from LangchainDocs
# Source link: https://docs.langchain.com/oss/python/deepagents/customization

# %%
import os
from typing import Literal
from tavily import TavilyClient
from langchain_google_genai import ChatGoogleGenerativeAI 
from deepagents import create_deep_agent

# %% [markdown]
# # Model

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
agent = create_deep_agent(model=model)

# %% [markdown]
# # System prompt

# %%
research_instructions = """\
You are an expert researcher. Your job is to conduct \
thorough research, and then write a polished report. \
"""
aget = create_deep_agent(
    system_prompt=research_instructions
)

# %% [markdown]
# # Tools

# %%
tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

def internet_search(
    query: str, 
    max_results: int = 5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool = False
):
    """Run a web search"""
    return tavily_client.search(
        query=query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic
    )

# %%
result = agent.invoke({"messages" : [
        {
            "role" : "user",
            "content" : "What do you think which langchain verion can I use?"
        }
    ]})
print(f"Last result of agent: {result["messages"][-1].content}")
# Out:
# Last result of agent: I've started a subagent to research the current stable and recommended versions of LangChain. I'll provide you with a recommendation once it has gathered the information.
